# %% [markdown]
# <h1>Feature Engineering</h1>

# %% [markdown]
# <h4>Importing dependencies</h4>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h4>Analyzing each City</h4>

# %%
df = pd.read_csv('europe_venues.csv', index_col=0)

# %%
# one hot encoding
europe_onehot = pd.get_dummies(df[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
europe_onehot['City'] = df['City'] 

# move neighborhood column to the first column
fixed_columns = [europe_onehot.columns[-1]] + list(europe_onehot.columns[:-1])
europe_onehot = europe_onehot[fixed_columns]

europe_onehot.sample(10)
# Out:
#             City  ATM  Accessories Store  Adult Boutique  Advertising Agency  \
# 12248   Toulouse    0                  0               0                   0
# 42573   Nijmegen    0                  0               0                   0
# 16070     Kaluga    0                  0               0                   0
# 85        Moscow    0                  0               0                   0
# 9275      Tyumen    0                  0               0                   0
# 6680   Ulyanovsk    0                  0               0                   0
# 1678     Kharkiv    0                  0               0                   0
# 13869  Makiyivka    0                  0               0                   0
# 4622    Voronezh    0                  0               0                   0
# 10775      Gomel    0                  0               0                   0
#
#        Afghan Restaurant  African Restaurant  Airport  Airport Food Court  \
# 12248                  0                   0        0                   0
# 42573                  0                   0        0                   0
# 16070                  0                   0        0                   0
# 85                     0                   0        0                   0
# 9275                   0                   0        0                   0
# 6680                   0                   0        0                   0
# 1678                   0                   0        0                   0
# 13869                  0                   0        0                   0
# 4622                   0                   0        0                   0
# 10775                  0                   0        0                   0
#
#        Airport Lounge     ...       West-Ukrainian Restaurant  Whisky Bar  \
# 12248               0     ...                               0           0
# 42573               0     ...                               0           0
# 16070               0     ...                               0           0
# 85                  0     ...                               0           0
# 9275                0     ...                               0           0
# 6680                0     ...                               0           0
# 1678                0     ...                               0           0
# 13869               0     ...                               0           0
# 4622                0     ...                               0           0
# 10775               0     ...                               0           0
#
#        Wine Bar  Wine Shop  Winery  Wings Joint  Women's Store  Yoga Studio  \
# 12248         0          0       0            0              0            0
# 42573         0          0       0            0              0            0
# 16070         0          0       0            0              0            0
# 85            0          0       0            0              0            0
# 9275          0          0       0            0              0            0
# 6680          0          0       0            0              0            0
# 1678          0          0       0            0              0            0
# 13869         0          0       0            0              0            0
# 4622          0          0       0            0              0            0
# 10775         0          0       0            0              0            0
#
#        Zoo  Zoo Exhibit
# 12248    0            0
# 42573    0            0
# 16070    0            0
# 85       0            0
# 9275     0            0
# 6680     0            0
# 1678     0            0
# 13869    0            0
# 4622     0            0
# 10775    0            0
#
# [10 rows x 562 columns]

# %% [markdown]
# <h4>Grouping rows by city and by taking the mean of the frequency of occurrence of each category</h4>

# %%
europe_grouped = europe_onehot.groupby('City').mean().reset_index()
europe_grouped.sample(10)
# Out:
#                     City  ATM  Accessories Store  Adult Boutique  \
# 173                 Iasi  0.0               0.00             0.0
# 289        Neue Neustadt  0.0               0.00             0.0
# 181          Kaliningrad  0.0               0.00             0.0
# 439                Tomsk  0.0               0.00             0.0
# 97   City of Westminster  0.0               0.00             0.0
# 390             Sector 5  0.0               0.01             0.0
# 323               Oviedo  0.0               0.00             0.0
# 62            Bratislava  0.0               0.00             0.0
# 206             Korolyov  0.0               0.00             0.0
# 414            Stuttgart  0.0               0.00             0.0
#
#      Advertising Agency  Afghan Restaurant  African Restaurant  Airport  \
# 173                 0.0                0.0                0.00      0.0
# 289                 0.0                0.0                0.00      0.0
# 181                 0.0                0.0                0.00      0.0
# 439                 0.0                0.0                0.00      0.0
# 97                  0.0                0.0                0.00      0.0
# 390                 0.0                0.0                0.00      0.0
# 323                 0.0                0.0                0.00      0.0
# 62                  0.0                0.0                0.00      0.0
# 206                 0.0                0.0                0.00      0.0
# 414                 0.0                0.0                0.01      0.0
#
#      Airport Food Court  Airport Lounge     ...       \
# 173                 0.0             0.0     ...
# 289                 0.0             0.0     ...
# 181                 0.0             0.0     ...
# 439                 0.0             0.0     ...
# 97                  0.0             0.0     ...
# 390                 0.0             0.0     ...
# 323                 0.0             0.0     ...
# 62                  0.0             0.0     ...
# 206                 0.0             0.0     ...
# 414                 0.0             0.0     ...
#
#      West-Ukrainian Restaurant  Whisky Bar  Wine Bar  Wine Shop  Winery  \
# 173                        0.0         0.0      0.00       0.00     0.0
# 289                        0.0         0.0      0.00       0.00     0.0
# 181                        0.0         0.0      0.00       0.00     0.0
# 439                        0.0         0.0      0.00       0.00     0.0
# 97                         0.0         0.0      0.01       0.01     0.0
# 390                        0.0         0.0      0.01       0.00     0.0
# 323                        0.0         0.0      0.03       0.00     0.0
# 62                         0.0         0.0      0.03       0.00     0.0
# 206                        0.0         0.0      0.00       0.00     0.0
# 414                        0.0         0.0      0.02       0.01     0.0
#
#      Wings Joint  Women's Store  Yoga Studio   Zoo  Zoo Exhibit
# 173          0.0            0.0         0.00  0.00          0.0
# 289          0.0            0.0         0.00  0.01          0.0
# 181          0.0            0.0         0.00  0.01          0.0
# 439          0.0            0.0         0.01  0.00          0.0
# 97           0.0            0.0         0.00  0.00          0.0
# 390          0.0            0.0         0.00  0.00          0.0
# 323          0.0            0.0         0.00  0.01          0.0
# 62           0.0            0.0         0.00  0.00          0.0
# 206          0.0            0.0         0.01  0.00          0.0
# 414          0.0            0.0         0.00  0.00          0.0
#
# [10 rows x 562 columns]

# %%
europe_grouped.shape
# Out:
# (499, 562)

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# <h4>Create the new dataframe with top 10 venues for each city</h4>

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['City']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
cities_venues_sorted = pd.DataFrame(columns=columns)
cities_venues_sorted['City'] = europe_grouped['City']

for ind in np.arange(europe_grouped.shape[0]):
    cities_venues_sorted.iloc[ind, 1:] = return_most_common_venues(europe_grouped.iloc[ind, :], num_top_venues)

cities_venues_sorted.sample(10)
# Out:
#            City 1st Most Common Venue        2nd Most Common Venue  \
# 93    Chernihiv           Coffee Shop                         Park
# 94   Chernivtsi                  Café                  Coffee Shop
# 2        Abakan                  Park                         Café
# 214     Krefeld           Supermarket                         Café
# 24     Augsburg    Italian Restaurant                         Café
# 331        Pecs           Coffee Shop                          Bar
# 288     Nazran'                  Café  Eastern European Restaurant
# 151   Goeteborg           Coffee Shop                        Hotel
# 418      Sutton                   Pub                         Park
# 434     Tilburg                   Bar                         Café
#
#             3rd Most Common Venue 4th Most Common Venue  \
# 93             Italian Restaurant           Supermarket
# 94                            Gym            Restaurant
# 2               Mobile Phone Shop           Coffee Shop
# 214                Ice Cream Shop    Italian Restaurant
# 24                    Beer Garden            Steakhouse
# 331                          Café            Restaurant
# 288           Monument / Landmark                 Hotel
# 151                  Burger Joint                  Café
# 418                   Coffee Shop                  Café
# 434  Theme Park Ride / Attraction            Restaurant
#
#        5th Most Common Venue 6th Most Common Venue  \
# 93      Gym / Fitness Center         Historic Site
# 94                     Plaza  Gym / Fitness Center
# 2               Burger Joint            Theme Park
# 214                Drugstore     German Restaurant
# 24         German Restaurant                   Bar
# 331                    Plaza        Scenic Lookout
# 288            Train Station                  Farm
# 151  Scandinavian Restaurant                   Pub
# 418              Supermarket      Sushi Restaurant
# 434                     Park           Supermarket
#
#             7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 93                            Pub           Pizza Place                 Hotel
# 94                           Park  Fast Food Restaurant           Pizza Place
# 2                Sushi Restaurant           Pizza Place                 Hotel
# 214              Greek Restaurant    Spanish Restaurant    Chinese Restaurant
# 24             Turkish Restaurant                Bakery                 Hotel
# 331          Fast Food Restaurant                Bakery                  Park
# 288                Farmers Market  Fast Food Restaurant    Falafel Restaurant
# 151  Theme Park Ride / Attraction              Wine Bar    Italian Restaurant
# 418             Korean Restaurant    Italian Restaurant        Tennis Stadium
# 434                   Zoo Exhibit           Coffee Shop     Electronics Store
#
#     10th Most Common Venue
# 93                  Church
# 94                   Hotel
# 2            Grocery Store
# 214                    Gym
# 24            Burger Joint
# 331            Beer Garden
# 288           Fishing Spot
# 151     Seafood Restaurant
# 418              Gastropub
# 434          Shopping Mall

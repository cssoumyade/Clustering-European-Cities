# %% [markdown]
# <h1>Feature Engineering & Clustering</h1>

# %% [markdown]
# <h4>Importing dependencies</h4>

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# <h4>Analyzing each City</h4>

# %%
df = pd.read_csv('europe_venues.csv', index_col=0)

# %%
# one hot encoding
europe_onehot = pd.get_dummies(df[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
europe_onehot['City'] = df['City'] 

# move neighborhood column to the first column
fixed_columns = [europe_onehot.columns[-1]] + list(europe_onehot.columns[:-1])
europe_onehot = europe_onehot[fixed_columns]

europe_onehot.sample(10)
# Out:
#              City  ATM  Accessories Store  Adult Boutique  Advertising Agency  \
# 9685        Penza    0                  0               0                   0
# 12527  Sevastopol    0                  0               0                   0
# 1033     Budapest    0                  0               0                   0
# 31233       Torun    0                  0               0                   0
# 29558      Verona    0                  0               0                   0
# 31740        Linz    0                  0               0                   0
# 42674    Grenoble    0                  0               0                   0
# 43507        Pecs    0                  0               0                   0
# 32513     Harburg    0                  0               0                   0
# 8517       Poznan    0                  0               0                   0
#
#        Afghan Restaurant  African Restaurant  Airport  Airport Food Court  \
# 9685                   0                   0        0                   0
# 12527                  0                   0        0                   0
# 1033                   0                   0        0                   0
# 31233                  0                   0        0                   0
# 29558                  0                   0        0                   0
# 31740                  0                   0        0                   0
# 42674                  0                   0        0                   0
# 43507                  0                   0        0                   0
# 32513                  0                   0        0                   0
# 8517                   0                   0        0                   0
#
#        Airport Lounge     ...       West-Ukrainian Restaurant  Whisky Bar  \
# 9685                0     ...                               0           0
# 12527               0     ...                               0           0
# 1033                0     ...                               0           0
# 31233               0     ...                               0           0
# 29558               0     ...                               0           0
# 31740               0     ...                               0           0
# 42674               0     ...                               0           0
# 43507               0     ...                               0           0
# 32513               0     ...                               0           0
# 8517                0     ...                               0           0
#
#        Wine Bar  Wine Shop  Winery  Wings Joint  Women's Store  Yoga Studio  \
# 9685          0          0       0            0              0            0
# 12527         0          0       0            0              0            0
# 1033          0          0       0            0              0            0
# 31233         0          0       0            0              0            0
# 29558         0          0       0            0              0            0
# 31740         0          0       0            0              0            0
# 42674         0          0       0            0              0            0
# 43507         1          0       0            0              0            0
# 32513         0          0       0            0              0            0
# 8517          0          0       0            0              0            0
#
#        Zoo  Zoo Exhibit
# 9685     0            0
# 12527    0            0
# 1033     0            0
# 31233    0            0
# 29558    0            0
# 31740    0            0
# 42674    0            0
# 43507    0            0
# 32513    0            0
# 8517     0            0
#
# [10 rows x 562 columns]

# %% [markdown]
# <h4>Grouping rows by city and by taking the mean of the frequency of occurrence of each category</h4>

# %%
europe_grouped = europe_onehot.groupby('City').mean().reset_index()
europe_grouped.sample(10)
# Out:
#              City  ATM  Accessories Store  Adult Boutique  Advertising Agency  \
# 486      Yasenevo  0.0                0.0             0.0                 0.0
# 79      Cambridge  0.0                0.0             0.0                 0.0
# 383      Sarajevo  0.0                0.0             0.0                 0.0
# 376        Samara  0.0                0.0             0.0                 0.0
# 350         Prato  0.0                0.0             0.0                 0.0
# 146          Gent  0.0                0.0             0.0                 0.0
# 211     Krasnodar  0.0                0.0             0.0                 0.0
# 433  Thessaloniki  0.0                0.0             0.0                 0.0
# 199          Kiel  0.0                0.0             0.0                 0.0
# 339       Pitesti  0.0                0.0             0.0                 0.0
#
#      Afghan Restaurant  African Restaurant  Airport  Airport Food Court  \
# 486                0.0                0.00     0.00                 0.0
# 79                 0.0                0.01     0.00                 0.0
# 383                0.0                0.00     0.00                 0.0
# 376                0.0                0.00     0.00                 0.0
# 350                0.0                0.00     0.00                 0.0
# 146                0.0                0.00     0.00                 0.0
# 211                0.0                0.00     0.00                 0.0
# 433                0.0                0.00     0.00                 0.0
# 199                0.0                0.00     0.01                 0.0
# 339                0.0                0.00     0.00                 0.0
#
#      Airport Lounge     ...       West-Ukrainian Restaurant  Whisky Bar  \
# 486             0.0     ...                             0.0         0.0
# 79              0.0     ...                             0.0         0.0
# 383             0.0     ...                             0.0         0.0
# 376             0.0     ...                             0.0         0.0
# 350             0.0     ...                             0.0         0.0
# 146             0.0     ...                             0.0         0.0
# 211             0.0     ...                             0.0         0.0
# 433             0.0     ...                             0.0         0.0
# 199             0.0     ...                             0.0         0.0
# 339             0.0     ...                             0.0         0.0
#
#      Wine Bar  Wine Shop  Winery  Wings Joint  Women's Store  Yoga Studio  \
# 486      0.00       0.01    0.00          0.0            0.0         0.05
# 79       0.00       0.01    0.00          0.0            0.0         0.00
# 383      0.01       0.00    0.00          0.0            0.0         0.00
# 376      0.01       0.00    0.00          0.0            0.0         0.00
# 350      0.00       0.01    0.01          0.0            0.0         0.00
# 146      0.06       0.00    0.00          0.0            0.0         0.01
# 211      0.00       0.00    0.00          0.0            0.0         0.00
# 433      0.04       0.00    0.00          0.0            0.0         0.00
# 199      0.00       0.00    0.00          0.0            0.0         0.00
# 339      0.00       0.00    0.00          0.0            0.0         0.00
#
#      Zoo  Zoo Exhibit
# 486  0.0          0.0
# 79   0.0          0.0
# 383  0.0          0.0
# 376  0.0          0.0
# 350  0.0          0.0
# 146  0.0          0.0
# 211  0.0          0.0
# 433  0.0          0.0
# 199  0.0          0.0
# 339  0.0          0.0
#
# [10 rows x 562 columns]

# %%
europe_grouped.shape
# Out:
# (499, 562)

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# <h4>Create the new dataframe with top 10 venues for each city</h4>

# %%
num_top_venues = 7

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['City']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
cities_venues_sorted = pd.DataFrame(columns=columns)
cities_venues_sorted['City'] = europe_grouped['City']

for ind in np.arange(europe_grouped.shape[0]):
    cities_venues_sorted.iloc[ind, 1:] = return_most_common_venues(europe_grouped.iloc[ind, :], num_top_venues)

cities_venues_sorted.sample(10)
# Out:
#                   City 1st Most Common Venue 2nd Most Common Venue  \
# 168              Herne                  Park                  Café
# 482            Wroclaw                  Café              Beer Bar
# 348     Praga Poludnie                  Park          Cocktail Bar
# 402              Sofia                  Park                Bakery
# 3             Aberdeen                   Bar                 Hotel
# 207             Kosice                  Café            Restaurant
# 489  Yuzhno-Sakhalinsk           Coffee Shop            Restaurant
# 245               Lviv                 Hotel           Coffee Shop
# 456             Vantaa                  Café  Gym / Fitness Center
# 492         Zaporizhia           Coffee Shop  Gym / Fitness Center
#
#     3rd Most Common Venue 4th Most Common Venue  \
# 168                Bakery        Ice Cream Shop
# 482                   Pub                 Hotel
# 348               Theater                  Café
# 402               Theater    Italian Restaurant
# 3                    Café              Beer Bar
# 207                 Hotel           Pizza Place
# 489                 Hotel                   Gym
# 245              Wine Bar                Church
# 456           Pizza Place           Coffee Shop
# 492                  Café                  Park
#
#              5th Most Common Venue        6th Most Common Venue  \
# 168             Italian Restaurant                  Supermarket
# 482  Vegetarian / Vegan Restaurant                 Burger Joint
# 348  Vegetarian / Vegan Restaurant                  Coffee Shop
# 402                    Coffee Shop                   Restaurant
# 3                             Park               Sandwich Place
# 207                         Bistro  Eastern European Restaurant
# 489                           Park          Sporting Goods Shop
# 245                          Plaza                    Bookstore
# 456           Himalayan Restaurant               Airport Lounge
# 492                   Dessert Shop           Italian Restaurant
#
#     7th Most Common Venue
# 168               Theater
# 482                  Park
# 348      Sushi Restaurant
# 402                  Café
# 3                     Pub
# 207                   Pub
# 489      Asian Restaurant
# 245                  Café
# 456     Recreation Center
# 492          Burger Joint

# %% [markdown]
# <h4>Clustering Cities</h4>

# %% [markdown]
# Run *k*-means to cluster the cities into 5 clusters

# %%
# set number of clusters
kclusters = 10

europe_grouped_clustering = europe_grouped.drop('City', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(europe_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([6, 1, 2, 5, 5, 6, 6, 6, 6, 2, 6, 1, 5, 5, 2, 5, 0, 5, 5, 5, 2, 4,
#        2, 5, 1, 2, 2, 6, 2, 4, 4, 6, 1, 0, 5, 2, 0, 5, 2, 5, 0, 3, 5, 0,
#        1, 2, 0, 6, 5, 3, 2, 3, 2, 1, 1, 1, 1, 5, 0, 3, 7, 5, 4, 4, 1, 5,
#        1, 1, 0, 3, 4, 5, 2, 0, 0, 1, 6, 2, 2, 3, 6, 0, 6, 6, 1, 4, 5, 1,
#        4, 0, 1, 2, 2, 0, 4, 5, 2, 5, 6, 0, 0, 5, 6, 3, 3, 5, 3, 3, 4, 4,
#        3, 0, 5, 3, 2, 1, 5, 3, 3, 5, 1, 3, 4, 5, 5, 5, 6, 6, 0, 1, 4, 1,
#        5, 1, 5, 4, 4, 6, 6, 4, 6, 5, 4, 1, 5, 1, 5, 6, 6, 5, 1, 5, 0, 4,
#        6, 4, 5, 5, 4, 1, 1, 5, 1, 4, 1, 1, 1, 5, 1, 2, 6, 6, 2, 4, 3, 0,
#        5, 5, 0, 4, 6, 5, 9, 0, 2, 8, 1, 1, 5, 2, 0, 2, 0, 0, 0, 0, 0, 2,
#        0, 1, 5, 3, 4, 2, 1, 2, 0, 4, 5, 4, 4, 0, 0, 0, 1, 0, 2, 0, 4, 2,
#        5, 6, 6, 6, 5, 3, 6, 3, 5, 1, 5, 5, 5, 2, 5, 5, 4, 5, 5, 4, 4, 5,
#        2, 3, 2, 5, 5, 0, 6, 1, 0, 2, 1, 2, 2, 6, 5, 3, 4, 3, 0, 5, 0, 5,
#        2, 4, 2, 5, 3, 0, 2, 1, 1, 4, 5, 5, 6, 1, 1, 4, 6, 0, 4, 0, 4, 4,
#        5, 1, 4, 1, 0, 3, 3, 5, 4, 2, 4, 4, 2, 5, 2, 3, 3, 3, 6, 2, 2, 4,
#        2, 0, 5, 1, 5, 1, 5, 0, 5, 0, 2, 4, 5, 1, 4, 6, 3, 1, 1, 6, 6, 5,
#        4, 2, 2, 0, 3, 2, 5, 4, 4, 2, 2, 4, 3, 2, 0, 5, 3, 4, 5, 5, 4, 3,
#        2, 0, 6, 2, 3, 4, 5, 5, 5, 0, 1, 1, 0, 5, 4, 4, 5, 4, 5, 1, 6, 5,
#        5, 4, 0, 6, 6, 6, 6, 6, 6, 4, 2, 0, 0, 0, 0, 0, 0, 0, 4, 4, 6, 2,
#        3, 4, 4, 3, 5, 0, 0, 1, 2, 3, 3, 4, 2, 2, 2, 5, 3, 5, 1, 2, 3, 2,
#        3, 3, 3, 2, 2, 4, 5, 2, 5, 4, 4, 1, 0, 6, 5, 4, 2, 4, 4, 2, 2, 0,
#        5, 5, 5, 1, 0, 1, 4, 5, 0, 0, 2, 0, 2, 5, 6, 6, 2, 5, 5, 4, 1, 5,
#        6, 5, 2, 4, 2, 0, 4, 2, 0, 0, 1, 0, 0, 3, 5, 3, 5, 1, 3, 3, 4, 4,
#        2, 5, 0, 0, 4, 2, 2, 4, 0, 6, 0, 2, 2, 2, 5])

# %% [markdown]
# <h4>Creating a new dataframe that includes the cluster as well as the top 10 venues for each city</h4>

# %%
df = pd.read_csv('europe_city_country.csv', index_col=0)
df = df.drop('Population', 1)
df.head()
# Out:
#                City         Country   Latitude  Longitude
# 0            Moscow          Russia  55.750446  37.617494
# 1            London  United Kingdom  51.507322  -0.127647
# 2  Saint Petersburg          Russia  59.938732  30.316229
# 3            Berlin         Germany  52.517036  13.388860
# 4            Madrid           Spain  40.416705  -3.703582

# %%
# add clustering labels
cities_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

europe_merged = df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
europe_merged = europe_merged.join(cities_venues_sorted.set_index('City'), on='City')

# %%
europe_merged.sample(10)
# Out:
#                   City      Country   Latitude   Longitude  Cluster Labels  \
# 467              Basel  Switzerland  47.558108    7.587826             5.0
# 317             Oviedo        Spain  43.360598   -5.844899             6.0
# 79         Vladivostok       Russia  43.115068  131.885577             4.0
# 172             Kaluga       Russia  54.510109   36.259811             0.0
# 169            Vitebsk      Belarus  55.193020   30.207044             4.0
# 415  Kamensk-Ural'skiy       Russia  56.436105   61.980762             2.0
# 238             Brasov      Romania  45.652309   25.610275             5.0
# 65           Krasnodar       Russia  45.035257   38.976481             0.0
# 107          Nuernberg      Germany  49.453872   11.077298             5.0
# 439           Lyublino       Russia  55.675638   37.761806             0.0
#
#     1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 467                  Café                 Hotel                   Bar
# 317    Spanish Restaurant            Restaurant           Coffee Shop
# 79                   Café           Coffee Shop            Restaurant
# 172           Coffee Shop                 Hotel                  Café
# 169                  Café         Shopping Mall           Coffee Shop
# 415         Shopping Mall                 Plaza                 Hotel
# 238                 Hotel           Coffee Shop                  Café
# 65             Restaurant                  Park           Coffee Shop
# 107                  Café           Coffee Shop          Burger Joint
# 439                  Park  Gym / Fitness Center     Health Food Store
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 467                 Plaza      Swiss Restaurant                  Park
# 317                   Bar                 Hotel                 Plaza
# 79      Korean Restaurant   Japanese Restaurant                 Beach
# 172  Gym / Fitness Center           Supermarket         Big Box Store
# 169            Restaurant                   Bar                  Park
# 415                  Café         Grocery Store        Scenic Lookout
# 238   Romanian Restaurant    Italian Restaurant                  Park
# 65                  Hotel    Italian Restaurant                   Pub
# 107                 Hotel                   Bar            Steakhouse
# 439           Coffee Shop                  Café        Clothing Store
#
#     7th Most Common Venue  8th Most Common Venue 9th Most Common Venue  \
# 467     French Restaurant             Art Museum          Cocktail Bar
# 317                  Park     Italian Restaurant              Wine Bar
# 79             Hookah Bar           Burger Joint        Scenic Lookout
# 172           Pizza Place                    Bar                 Plaza
# 169                 Plaza          Grocery Store           Pizza Place
# 415        Clothing Store     English Restaurant  Gym / Fitness Center
# 238                Bistro          Historic Site                 Plaza
# 65               Fountain                  Plaza                  Café
# 107                  Park  Franconian Restaurant                Castle
# 439             Multiplex                 Arcade    Salon / Barbershop
#
#     10th Most Common Venue
# 467     Italian Restaurant
# 317              BBQ Joint
# 79                    Park
# 172             Restaurant
# 169   Fast Food Restaurant
# 415     Italian Restaurant
# 238         Scenic Lookout
# 65        Asian Restaurant
# 107                Brewery
# 439                 Garden

# %% [markdown]
# <h4>Droping the rows containing NaN values</h4>

# %%
europe_merged.drop(europe_merged[np.isnan(europe_merged['Cluster Labels'])].index, inplace=True)

# %% [markdown]
# <h4>Visualizing the resulting clusters</h4>

# %%
# create map
latitude = 55.4649
longitude = 65.3054
europe_merged['Cluster Labels'] = europe_merged['Cluster Labels'].astype(int)
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=3)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(europe_merged['Latitude'], europe_merged['Longitude'], europe_merged['City'], europe_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ![alt text](map4.JPG "City clusters of Europe")

# %% [markdown]
# <h4>Examining each clusters</h4>

# %% [markdown]
# Cluster 1

# %%
europe_merged.loc[europe_merged['Cluster Labels'] == 0, europe_merged.columns[[0] + list(range(5, europe_merged.shape[1]))]]
# Out:
#                     City 1st Most Common Venue 2nd Most Common Venue  \
# 3                 Berlin           Coffee Shop                  Park
# 8              Bucharest           Coffee Shop                 Hotel
# 9                  Minsk           Coffee Shop                   Spa
# 10              Budapest           Coffee Shop                 Hotel
# 16               Kharkiv           Coffee Shop                  Park
# 17           Novosibirsk           Coffee Shop            Restaurant
# 18         Yekaterinburg           Coffee Shop                  Park
# 25                 Sofia                  Park                Bakery
# 26                Samara           Coffee Shop                 Beach
# 27                  Omsk           Coffee Shop            Restaurant
# 28                 Kazan           Coffee Shop                   Bar
# 29        Rostov-na-Donu           Coffee Shop                  Park
# 30           Chelyabinsk  Gym / Fitness Center           Coffee Shop
# 31                   Ufa                  Park            Hookah Bar
# 32                Dnipro           Coffee Shop  Gym / Fitness Center
# 36             Volgograd              Tea Room         Deli / Bodega
# 39                  Perm                  Café           Coffee Shop
# 42           Krasnoyarsk           Coffee Shop  Gym / Fitness Center
# 45               Saratov           Coffee Shop  Gym / Fitness Center
# 46              Voronezh                  Park           Coffee Shop
# 48            Zaporizhia           Coffee Shop  Gym / Fitness Center
# 63            Kryvyi Rih           Coffee Shop            Restaurant
# 65             Krasnodar            Restaurant                  Park
# 67             Ulyanovsk                  Park           Coffee Shop
# 73               Barnaul                   Gym           Coffee Shop
# 80               Irkutsk           Coffee Shop                   Pub
# 83            Khabarovsk           Coffee Shop  Gym / Fitness Center
# 84     Khabarovsk Vtoroy           Coffee Shop  Gym / Fitness Center
# 95                Tyumen           Coffee Shop                 Hotel
# 110                Tomsk                  Park           Coffee Shop
# ..                   ...                   ...                   ...
# 186             Murmansk  Gym / Fitness Center                  Park
# 191              Poltava           Coffee Shop                  Park
# 195          Cluj-Napoca                Bakery           Coffee Shop
# 198              Vologda           Coffee Shop  Gym / Fitness Center
# 204             Vladimir                  Park            Restaurant
# 207            Chernihiv           Coffee Shop                  Park
# 210            Constanta                   Gym                  Café
# 213                Brest                  Café           Coffee Shop
# 226             Sector 4           Coffee Shop  Gym / Fitness Center
# 245             Sector 5           Coffee Shop                 Hotel
# 261                Rivne           Coffee Shop                  Park
# 282              Mar'ino                  Park     Health Food Store
# 284               Khimki                  Park  Gym / Fitness Center
# 291             Ternopil           Coffee Shop                  Park
# 310           Kremenchuk           Coffee Shop                  Park
# 316             Sector 1           Coffee Shop                  Park
# 331    Vykhino-Zhulebino                  Park  Gym / Fitness Center
# 334           Zelenograd                  Park           Pizza Place
# 365                Pskov           Coffee Shop                  Café
# 373         Bila Tserkva           Coffee Shop                  Café
# 382              Engel's           Coffee Shop                  Park
# 411             Korolyov  Gym / Fitness Center           Coffee Shop
# 422             Yasenevo  Gym / Fitness Center                  Park
# 439             Lyublino                  Park  Gym / Fitness Center
# 460            Neukoelln                  Park           Coffee Shop
# 474          Bournemouth           Coffee Shop                 Beach
# 481            Mytishchi                  Park  Gym / Fitness Center
# 484             Bibirevo                  Park     Health Food Store
# 485  Khoroshevo-Mnevniki                  Park  Gym / Fitness Center
# 493           Gol'yanovo                  Park           Coffee Shop
#
#            3rd Most Common Venue     4th Most Common Venue  \
# 3                      Bookstore              Concert Hall
# 8                   Dessert Shop  Mediterranean Restaurant
# 9                            Bar              Cocktail Bar
# 10                        Bakery              Dessert Shop
# 16          Gym / Fitness Center                 Wine Shop
# 17                    Hookah Bar                       Pub
# 18                    Restaurant      Gym / Fitness Center
# 25                       Theater        Italian Restaurant
# 26          Gym / Fitness Center          Pedestrian Plaza
# 27                           Gym                      Park
# 28                          Park                   Theater
# 29                          Café                  Wine Bar
# 30                         Hotel                 BBQ Joint
# 31                   Coffee Shop      Gym / Fitness Center
# 32                      Tea Room              Dance Studio
# 36                          Café      Gym / Fitness Center
# 39                          Park                       Bar
# 42                Scenic Lookout                      Park
# 45                  Dessert Shop                      Park
# 46                         Hotel                      Café
# 48                          Café                      Park
# 63                   Supermarket                      Café
# 65                   Coffee Shop                     Hotel
# 67                 Grocery Store      Gym / Fitness Center
# 73                     Multiplex              Soccer Field
# 80                          Café          Pedestrian Plaza
# 83                    Restaurant                      Café
# 84                    Restaurant                      Café
# 95                          Park                Restaurant
# 110         Gym / Fitness Center        Italian Restaurant
# ..                           ...                       ...
# 186               Cosmetics Shop                       Bar
# 191                         Café                Restaurant
# 195                   Restaurant                      Café
# 198                         Café           Bed & Breakfast
# 204                  Coffee Shop                       Gym
# 207           Italian Restaurant               Supermarket
# 210                  Coffee Shop                    Lounge
# 213                Historic Site               Supermarket
# 226                         Park                     Hotel
# 245                          Gym              Dessert Shop
# 261                   Restaurant               Pizza Place
# 282                  Coffee Shop            Cosmetics Shop
# 284                  Coffee Shop         Health Food Store
# 291           Italian Restaurant               Pizza Place
# 310         Gym / Fitness Center                Restaurant
# 316                 Dessert Shop                    Lounge
# 331            Health Food Store               Coffee Shop
# 334            Convenience Store                   Stables
# 365                          Bar                     Hotel
# 373  Eastern European Restaurant                      Park
# 382                 Dessert Shop                     Beach
# 411                         Park                      Café
# 422                  Coffee Shop         Health Food Store
# 439            Health Food Store               Coffee Shop
# 460                          Bar               Pizza Place
# 474                          Pub                      Park
# 481                  Coffee Shop                   Theater
# 484                  Supermarket                  Fountain
# 485                          Spa               Coffee Shop
# 493           Photography Studio      Gym / Fitness Center
#
#     5th Most Common Venue        6th Most Common Venue  \
# 3          Ice Cream Shop                       Garden
# 8             Pizza Place                         Park
# 9                   Hotel                         Park
# 10           Cocktail Bar                     Wine Bar
# 16             Restaurant                        Hotel
# 17           Cocktail Bar                      Theater
# 18                    Bar               Cosmetics Shop
# 25            Coffee Shop                   Restaurant
# 26                   Park         Caucasian Restaurant
# 27             Hookah Bar                 Dessert Shop
# 28          Historic Site                     Boutique
# 29   Gym / Fitness Center                        Hotel
# 30                 Bakery                         Park
# 31                  Plaza                        Hotel
# 32                 Arcade         Caucasian Restaurant
# 36            Coffee Shop                Historic Site
# 39           Cocktail Bar                 Dessert Shop
# 42              Gastropub                 Concert Hall
# 45                    Gym                          Pub
# 46   Gym / Fitness Center                   Restaurant
# 48           Dessert Shop           Italian Restaurant
# 63                 Bakery                        Hotel
# 65     Italian Restaurant                          Pub
# 67       Sushi Restaurant                    Racetrack
# 73            Art Gallery  Eastern European Restaurant
# 80                  Hotel         Gym / Fitness Center
# 83                   Park                       Bistro
# 84                 Bistro                         Park
# 95                 Bakery         Gym / Fitness Center
# 110                   Gym             Asian Restaurant
# ..                    ...                          ...
# 186                  Café                       Arcade
# 191                 Hotel         Gym / Fitness Center
# 195                   Pub                          Bar
# 198               Theater                   Hookah Bar
# 204        Scenic Lookout                        Hotel
# 207  Gym / Fitness Center                Historic Site
# 210          Cocktail Bar                  Pizza Place
# 213                  Park         Gym / Fitness Center
# 226          Dessert Shop                   Restaurant
# 245  Gym / Fitness Center                         Park
# 261                  Café         Gym / Fitness Center
# 282                  Café         Gym / Fitness Center
# 284            Restaurant           Italian Restaurant
# 291             Nightclub                  Supermarket
# 310                  Café                 Dessert Shop
# 316                   Gym                   Restaurant
# 331                   Gym           Italian Restaurant
# 334        Clothing Store                        Trail
# 365            Waterfront                   Restaurant
# 373                   Gym                  Supermarket
# 382            Restaurant               Clothing Store
# 411           Pizza Place         Caucasian Restaurant
# 422           Yoga Studio                 Gourmet Shop
# 439                  Café               Clothing Store
# 460        Ice Cream Shop                         Café
# 474                  Café           Italian Restaurant
# 481             Surf Spot         Caucasian Restaurant
# 484  Gym / Fitness Center                       Garden
# 485          Concert Hall                        Hotel
# 493     Health Food Store               Cosmetics Shop
#
#            7th Most Common Venue
# 3                         Bakery
# 8            Romanian Restaurant
# 9             Italian Restaurant
# 10            Italian Restaurant
# 16                         Plaza
# 17                     BBQ Joint
# 18     Middle Eastern Restaurant
# 25                          Café
# 26                          Café
# 27                  Noodle House
# 28                         Hotel
# 29                    Restaurant
# 30                    Restaurant
# 31                 Shopping Mall
# 32                 Shopping Mall
# 36                          Park
# 39                     Bookstore
# 42            Italian Restaurant
# 45              Sushi Restaurant
# 46                    Hookah Bar
# 48                  Burger Joint
# 63                          Park
# 65                      Fountain
# 67                          Pool
# 73                          Park
# 80                       Theater
# 83                 Movie Theater
# 84              Pedestrian Plaza
# 95                         Plaza
# 110                  Pizza Place
# ..                           ...
# 186         Fast Food Restaurant
# 191                          Gym
# 195           Italian Restaurant
# 198                         Park
# 204  Eastern European Restaurant
# 207                          Pub
# 210                 Dessert Shop
# 213                        Hotel
# 226           Italian Restaurant
# 245                  Pizza Place
# 261                        Plaza
# 282           Salon / Barbershop
# 284               Cosmetics Shop
# 291      Health & Beauty Service
# 310               Soccer Stadium
# 316     Mediterranean Restaurant
# 331                    Pet Store
# 334                  Coffee Shop
# 365                Historic Site
# 373                Historic Site
# 382         Gym / Fitness Center
# 411           Italian Restaurant
# 422                          Spa
# 439                    Multiplex
# 460                     Beer Bar
# 474                        Hotel
# 481                  Supermarket
# 484                      Stables
# 485                    Pet Store
# 493                    Pet Store
#
# [75 rows x 8 columns]

# %% [markdown]
# Cluster 2

# %%
europe_merged.loc[europe_merged['Cluster Labels'] == 1, europe_merged.columns[[0] + list(range(5, europe_merged.shape[1]))]]
# Out:
#                  City 1st Most Common Venue        2nd Most Common Venue  \
# 6                Rome         Historic Site                        Plaza
# 40              Koeln    Italian Restaurant                         Café
# 41             Naples           Pizza Place           Italian Restaurant
# 43              Turin                 Plaza               Ice Cream Shop
# 66            Palermo                 Plaza           Italian Restaurant
# 75              Essen                  Café           Italian Restaurant
# 77          Stuttgart                   Bar            German Restaurant
# 78           Dortmund                  Café                         Park
# 81              Genoa    Italian Restaurant                        Plaza
# 91             Bremen                  Café                          Bar
# 98           Hannover                  Café                  Coffee Shop
# 105          Duisburg            Restaurant               Ice Cream Shop
# 142            Bochum                Bakery                         Café
# 146     Bochum-Hordel                Bakery                         Café
# 155           Bologna    Italian Restaurant                        Plaza
# 165          Florence    Italian Restaurant               Ice Cream Shop
# 178         Bielefeld           Supermarket                          Bar
# 183         Volzhskiy    Italian Restaurant                        River
# 201              Bonn                   Pub                        Plaza
# 224           Catania           Pizza Place                         Café
# 228         Karlsruhe                  Café           Italian Restaurant
# 236              Bari    Italian Restaurant                        Hotel
# 243         Wiesbaden     German Restaurant                         Café
# 247          Muenster                  Café            German Restaurant
# 248     Gelsenkirchen                  Park               Ice Cream Shop
# 251            Aachen                  Café                          Bar
# 253  Moenchengladbach           Supermarket            German Restaurant
# 255          Augsburg    Italian Restaurant                         Café
# 266            Altona                 Beach           Seafood Restaurant
# 274          Chemnitz     German Restaurant                        Hotel
# ..                ...                   ...                          ...
# 286           Krefeld           Supermarket                         Café
# 296     Halle (Saale)                  Café                  Supermarket
# 297     Hamburg-Mitte     German Restaurant                   Lighthouse
# 299              Kiel                  Café                  Supermarket
# 305         Magdeburg                 Hotel                    Drugstore
# 313     Neue Neustadt                 Hotel                    Drugstore
# 327        Oberhausen    Turkish Restaurant                  Supermarket
# 328            Verona    Italian Restaurant                         Café
# 360            Padova    Italian Restaurant                         Café
# 361            Erfurt                  Café                  Supermarket
# 364           Harburg           Supermarket                  Gas Station
# 368         Charleroi    Italian Restaurant                   Restaurant
# 375             Hagen           Supermarket                         Café
# 376           Gliwice           Supermarket  Eastern European Restaurant
# 378           Rostock                 Hotel                  Supermarket
# 383            Burgas           Supermarket                  Pizza Place
# 384            Kassel                  Café            German Restaurant
# 399           Trieste                 Hotel                        Plaza
# 406              Hamm           Supermarket                    Drugstore
# 407             Mainz     German Restaurant                         Café
# 408           Brescia    Italian Restaurant               Ice Cream Shop
# 417      Saarbruecken                  Café            German Restaurant
# 419           Taranto           Pizza Place           Italian Restaurant
# 438             Herne                  Park                         Café
# 444          Muelheim                  Café                         Park
# 463        Osnabrueck           Supermarket                          Bar
# 469          Solingen           Supermarket                        Hotel
# 478        Leverkusen    Italian Restaurant                         Park
# 483         Oldenburg                  Café            German Restaurant
# 486            Modena    Italian Restaurant                         Café
#
#     3rd Most Common Venue   4th Most Common Venue  5th Most Common Venue  \
# 6          Ice Cream Shop          Sandwich Place    Monument / Landmark
# 40                  Hotel                    Park  Vietnamese Restaurant
# 41                  Plaza                    Café          Historic Site
# 43                   Café                   Hotel          Historic Site
# 66            Pizza Place          Ice Cream Shop                    Bar
# 75     Falafel Restaurant            Burger Joint                    Pub
# 77                   Café          Ice Cream Shop           Cocktail Bar
# 78     Turkish Restaurant                     Pub                    Bar
# 81                  Hotel          Ice Cream Shop                   Café
# 91     Italian Restaurant       German Restaurant                  Hotel
# 98                  Plaza                    Park              Irish Pub
# 105           Supermarket         Thai Restaurant                   Park
# 142                  Park             Supermarket       Greek Restaurant
# 146                  Park       German Restaurant            Supermarket
# 155        Ice Cream Shop                    Café               Wine Bar
# 165                 Hotel                   Plaza         Sandwich Place
# 178    Italian Restaurant                    Café             Restaurant
# 183                 Hotel             Snack Place             Campground
# 201    Italian Restaurant       German Restaurant                   Café
# 224    Italian Restaurant            Cocktail Bar                  Plaza
# 228        Ice Cream Shop       German Restaurant            Coffee Shop
# 236           Pizza Place                    Café             Restaurant
# 243                  Park                   Hotel     Falafel Restaurant
# 247    Italian Restaurant             Coffee Shop                   Park
# 248            Restaurant                 Theater   Gym / Fitness Center
# 251    Italian Restaurant                  Bakery                   Park
# 253      Greek Restaurant               Drugstore   Gym / Fitness Center
# 255           Beer Garden              Steakhouse      German Restaurant
# 266                 Hotel          Ice Cream Shop             Restaurant
# 274           Supermarket               Drugstore          Train Station
# ..                    ...                     ...                    ...
# 286        Ice Cream Shop      Italian Restaurant              Drugstore
# 296                 Hotel                     Bar                  Plaza
# 297       Harbor / Marina                  Island                  Hotel
# 299                 Hotel             Coffee Shop           Burger Joint
# 305           Supermarket                    Park     Italian Restaurant
# 313           Supermarket                    Park     Italian Restaurant
# 327                  Café          Clothing Store            Coffee Shop
# 328                 Plaza             Pizza Place      Trattoria/Osteria
# 360           Pizza Place                   Plaza                    Pub
# 361         Big Box Store                    Park              Drugstore
# 364           Golf Course                   Hotel          Train Station
# 368      Greek Restaurant                 Brewery               Friterie
# 375                 Hotel                  Bakery          Shopping Mall
# 376                   Pub      Italian Restaurant              Gastropub
# 378            Restaurant               Nightclub      German Restaurant
# 383                  Café             Coffee Shop                   Park
# 384           Supermarket             Art Gallery                  Hotel
# 399                  Café          Ice Cream Shop                  Beach
# 406         Big Box Store    Gym / Fitness Center     Chinese Restaurant
# 407           Coffee Shop                Wine Bar                  Plaza
# 408                  Café            Cocktail Bar             Piadineria
# 417           Supermarket             Coffee Shop                    Bar
# 419                  Café      Seafood Restaurant            Beer Garden
# 438                Bakery          Ice Cream Shop     Italian Restaurant
# 444                   Pub       German Restaurant            Supermarket
# 463                  Café               Nightclub                  Hotel
# 469                  Café       German Restaurant              Drugstore
# 478                  Café          Ice Cream Shop            Zoo Exhibit
# 483           Supermarket  Furniture / Home Store         Farmers Market
# 486        Ice Cream Shop             Pizza Place                  Plaza
#
#       6th Most Common Venue          7th Most Common Venue
# 6        Italian Restaurant                         Church
# 40                    Plaza                     Art Museum
# 41           Ice Cream Shop                          Hotel
# 43   Piedmontese Restaurant             Italian Restaurant
# 66            Historic Site                         Museum
# 75                    Plaza               Doner Restaurant
# 77       Italian Restaurant                           Park
# 78                    Hotel             Italian Restaurant
# 81            Historic Site                    Pizza Place
# 91               Restaurant                          Plaza
# 98              Pizza Place             Italian Restaurant
# 105                    Café             Turkish Restaurant
# 142                     Bar              German Restaurant
# 146                 Theater                 Ice Cream Shop
# 155                   Hotel                 Sandwich Place
# 165              Art Museum                         Church
# 178               Drugstore                          Plaza
# 183            Dessert Shop                            Gym
# 201                  Museum                   Burger Joint
# 224            Dessert Shop                Bed & Breakfast
# 228              Restaurant                            Bar
# 236          Ice Cream Shop                            Pub
# 243                     Bar                          Plaza
# 247                   Hotel                    Supermarket
# 248          Soccer Stadium                           Café
# 251             Coffee Shop                    Supermarket
# 253                   Hotel                 Ice Cream Shop
# 255                     Bar             Turkish Restaurant
# 266                  Bakery                           Park
# 274                    Café                 Ice Cream Shop
# ..                      ...                            ...
# 286       German Restaurant               Greek Restaurant
# 296             Gas Station                      Drugstore
# 297                   Field                   Fish Taverna
# 299               Drugstore                 Clothing Store
# 305       German Restaurant                          Plaza
# 313                   Plaza                           Café
# 327            Burger Joint             Italian Restaurant
# 328                   Hotel                  Historic Site
# 360          Ice Cream Shop                     Restaurant
# 361          Ice Cream Shop                          Plaza
# 364               Rest Area            American Restaurant
# 368                     Bar              French Restaurant
# 375              Steakhouse                    Gas Station
# 376          History Museum                  Train Station
# 378                  Bakery               Greek Restaurant
# 383                  Market                 Sandwich Place
# 384              Art Museum           Gym / Fitness Center
# 399      Italian Restaurant              Trattoria/Osteria
# 406      Turkish Restaurant                 Ice Cream Shop
# 407          Ice Cream Shop                           Park
# 408                   Plaza                    Pizza Place
# 417                   Hotel               Sushi Restaurant
# 419           Movie Theater                      Nightclub
# 438             Supermarket                        Theater
# 444      Italian Restaurant  Vegetarian / Vegan Restaurant
# 463                     Pub                    Gas Station
# 469               Gastropub                         Bakery
# 478    Gym / Fitness Center               Greek Restaurant
# 483                     Bar                          Plaza
# 486               Gastropub                   Cocktail Bar
#
# [61 rows x 8 columns]

# %% [markdown]
# Cluster 3

# %%
europe_merged.loc[europe_merged['Cluster Labels'] == 2, europe_merged.columns[[0] + list(range(5, europe_merged.shape[1]))]]
# Out:
#                          City        1st Most Common Venue  \
# 33                    Donetsk                          Gym
# 57                  Tol'yatti                         Café
# 90                   Orenburg                         Park
# 97                    Lipetsk                         Park
# 99                      Penza                Shopping Mall
# 106                 Astrakhan                         Café
# 108               Makhachkala                         Park
# 113                  Kemerovo                   Restaurant
# 123                   Luhansk                  Supermarket
# 129                   Bryansk                         Café
# 135                     Kursk                  Coffee Shop
# 139              Khmelnytskyi                   Restaurant
# 145              Nizhny Tagil  Eastern European Restaurant
# 147                 Makiyivka                  Pizza Place
# 149                    Kaunas                   Restaurant
# 152                  Mahilyow                Shopping Mall
# 154                 Bydgoszcz                   Restaurant
# 156                Stavropol'                   Restaurant
# 158                  Ulan-Ude                   Restaurant
# 161              Arkhangel'sk                  Pizza Place
# 164                 Vinnytsia                  Coffee Shop
# 192               Vladikavkaz                   Restaurant
# 193                    Hrodna             Department Store
# 196               Cherepovets                   Restaurant
# 205                     Chita               Sandwich Place
# 211                   Saransk                        Plaza
# 214                    Surgut                  Coffee Shop
# 217                  Cherkasy                         Café
# 220                      Sumy                   Restaurant
# 229                  Zhytomyr                         Café
# ..                        ...                          ...
# 337                  Novi Sad                   Restaurant
# 340                     Lutsk                  Pizza Place
# 370                   Tilburg                          Bar
# 371                  Balakovo                   Restaurant
# 388                  Klaipeda                   Restaurant
# 389                    Zabrze                   Restaurant
# 390                  Zlatoust                   Restaurant
# 392                    Vantaa                         Café
# 393                   Syzran'                   Restaurant
# 394                     Bytom                  Gas Station
# 398  Petropavlovsk-Kamchatsky          Sporting Goods Shop
# 415         Kamensk-Ural'skiy                Shopping Mall
# 423                   Podolsk         Gym / Fitness Center
# 427             Bielsko-Biala                Shopping Mall
# 428         Yuzhno-Sakhalinsk                  Coffee Shop
# 429               Almere Stad                   Restaurant
# 436                   Miskolc                          Bar
# 442                     Bacau                         Café
# 454                 Berezniki                         Café
# 455                Volgodonsk                         Park
# 457                   Pitesti                   Restaurant
# 458                     Miass                         Café
# 459                    Abakan                         Park
# 462             Novocherkassk            Mobile Phone Shop
# 468                    Zenica                   Restaurant
# 487                  Nijmegen                   Restaurant
# 492                 Melitopol                  Coffee Shop
# 496                 Ussuriysk            Electronics Store
# 497                  Tiraspol                         Café
# 498                      Pecs                  Coffee Shop
#
#     2nd Most Common Venue         3rd Most Common Venue  \
# 33             Restaurant                          Park
# 57   Gym / Fitness Center                   Pizza Place
# 90             Restaurant                         Hotel
# 97                    Gym                    Restaurant
# 99                   Café                          Park
# 106           Coffee Shop                    Restaurant
# 108                 Hotel                          Café
# 113                Bakery                   Coffee Shop
# 123            Restaurant                   Coffee Shop
# 129           Coffee Shop                          Park
# 135                  Park                    Restaurant
# 139           Coffee Shop          Gym / Fitness Center
# 145   Sporting Goods Shop                    Hookah Bar
# 147            Restaurant                          Café
# 149                  Park                         Hotel
# 152                  Café                         Plaza
# 154                  Café                         Hotel
# 156                  Park                        Bakery
# 158                  Café              Asian Restaurant
# 161                   Gym                   Coffee Shop
# 164                  Café                    Restaurant
# 192                  Café   Eastern European Restaurant
# 193            Restaurant                 Big Box Store
# 196  Gym / Fitness Center                          Park
# 205         Shopping Mall          Gym / Fitness Center
# 211           Coffee Shop                         Hotel
# 214  Fast Food Restaurant             Electronics Store
# 217           Coffee Shop                    Restaurant
# 220           Coffee Shop                 Shopping Mall
# 229           Coffee Shop                    Restaurant
# ..                    ...                           ...
# 337    Italian Restaurant                           Bar
# 340            Restaurant                           Gym
# 370                  Café  Theme Park Ride / Attraction
# 371                  Café                   Coffee Shop
# 388                 Beach                           Pub
# 389  Fast Food Restaurant                   Gas Station
# 390         Big Box Store                 Grocery Store
# 392  Gym / Fitness Center                   Pizza Place
# 393             BBQ Joint                 Shopping Mall
# 394  Fast Food Restaurant                   Pizza Place
# 398              Ski Area                    Restaurant
# 415                 Plaza                         Hotel
# 423                  Park                          Café
# 427                 Hotel                    Restaurant
# 428            Restaurant                         Hotel
# 429        Ice Cream Shop              Sushi Restaurant
# 436            Restaurant                      Bus Stop
# 442            Restaurant              Department Store
# 454                 Hotel                          Park
# 455     Food & Drink Shop           Japanese Restaurant
# 457                   Pub                          Park
# 458              Ski Area                    Restaurant
# 459                  Café             Mobile Phone Shop
# 462          Dessert Shop                    Restaurant
# 468                 Hotel                  Dessert Shop
# 487                   Bar                           Pub
# 492            Restaurant                     BBQ Joint
# 496            Restaurant                 Shopping Mall
# 497         Shopping Mall                     Nightclub
# 498                   Bar                          Café
#
#            4th Most Common Venue        5th Most Common Venue  \
# 33             Electronics Store         Gym / Fitness Center
# 57                          Park                  Coffee Shop
# 90             Electronics Store                  Coffee Shop
# 97                     Gastropub                Shopping Mall
# 99                           Bar                Grocery Store
# 106                          Gym                        Hotel
# 108                   Restaurant  Eastern European Restaurant
# 113                  Gas Station                       Lounge
# 123                         Café                      Brewery
# 129                  Pizza Place                Shopping Mall
# 135                        Hotel                Grocery Store
# 139                         Café                         Park
# 145                  Pizza Place                  Coffee Shop
# 147            Electronics Store                          Gym
# 149                    BBQ Joint           Italian Restaurant
# 152                         Park                  Coffee Shop
# 154  Eastern European Restaurant                    Nightclub
# 156                          Gym                  Coffee Shop
# 158                          Bar                  Pizza Place
# 161               Clothing Store                          Pub
# 164                         Park                        Plaza
# 192                  Snack Place                Shopping Mall
# 193                         Café                  Coffee Shop
# 196                         Café                Shopping Mall
# 205                  Coffee Shop             Asian Restaurant
# 211             Department Store                         Café
# 214                         Café                         Park
# 217                         Park                  Pizza Place
# 220                         Park               Cosmetics Shop
# 229                        Hotel  Eastern European Restaurant
# ..                           ...                          ...
# 337                  Coffee Shop                          Pub
# 340                         Park                         Café
# 370                   Restaurant                         Park
# 371          Japanese Restaurant                Shopping Mall
# 388                        Plaza                  Coffee Shop
# 389                          Pub                  Supermarket
# 390                  Supermarket                        Hotel
# 392                  Coffee Shop         Himalayan Restaurant
# 393                      Brewery               Soccer Stadium
# 394                        Hotel       Furniture / Home Store
# 398                         Café                 Cocktail Bar
# 415                         Café                Grocery Store
# 423                   Restaurant                  Supermarket
# 427         Fast Food Restaurant           Italian Restaurant
# 428                          Gym                         Park
# 429         Gym / Fitness Center                          Bar
# 436                  Supermarket           Italian Restaurant
# 442           Italian Restaurant                       Lounge
# 454           Italian Restaurant                    BBQ Joint
# 455                          Gym                   Steakhouse
# 457                         Café                        Hotel
# 458                  Coffee Shop               Sandwich Place
# 459                  Coffee Shop                 Burger Joint
# 462               History Museum                         Park
# 468                  Coffee Shop                       Lounge
# 487                  Coffee Shop                         Park
# 492                Shopping Mall                         Café
# 496               Cosmetics Shop           Chinese Restaurant
# 497            Mobile Phone Shop                        Hotel
# 498                   Restaurant                        Plaza
#
#            6th Most Common Venue        7th Most Common Venue
# 33            Italian Restaurant                         Café
# 57                           Gym                       Lounge
# 90                          Café                Shopping Mall
# 97          Gym / Fitness Center                         Café
# 99                    Restaurant             Department Store
# 106                         Park                    Multiplex
# 108                  Coffee Shop         Caucasian Restaurant
# 113                      Theater                         Park
# 123                         Park                          Gym
# 129            Food & Drink Shop                        Plaza
# 135                        Plaza                Shopping Mall
# 139                  Gas Station           Italian Restaurant
# 145                         Café                Big Box Store
# 147                Shopping Mall         Gym / Fitness Center
# 149               History Museum  Eastern European Restaurant
# 152                        Hotel                     Bus Stop
# 154             Sushi Restaurant                  Coffee Shop
# 156                        Plaza                         Café
# 158                        Hotel                Grocery Store
# 161                    Multiplex                Shopping Mall
# 164                       Bakery                        Hotel
# 192                 Dessert Shop    Middle Eastern Restaurant
# 193                         Park                Shopping Mall
# 196                 Hockey Arena                Grocery Store
# 205                         Café                 Skating Rink
# 211                  Pizza Place               Soccer Stadium
# 214         Gym / Fitness Center                        Hotel
# 217                        Hotel                        Beach
# 220                        Hotel                         Café
# 229                         Park                  Gas Station
# ..                           ...                          ...
# 337                  Pizza Place                  Music Venue
# 340                  Coffee Shop                  Gas Station
# 370                  Supermarket                  Zoo Exhibit
# 371  Eastern European Restaurant                  Karaoke Bar
# 388                 Burger Joint                       Bakery
# 389                Train Station                  Pizza Place
# 390                National Park                         Park
# 392               Airport Lounge            Recreation Center
# 393                    Nightclub                   Steakhouse
# 394                   Restaurant                       Lounge
# 398                 Burger Joint                Shopping Mall
# 415               Scenic Lookout               Clothing Store
# 423                  Pizza Place         Fast Food Restaurant
# 427                  Gas Station  Eastern European Restaurant
# 428          Sporting Goods Shop             Asian Restaurant
# 429                         Park                        Hotel
# 436                    Gastropub         Fast Food Restaurant
# 442                        Hotel                  Pizza Place
# 454          Sporting Goods Shop                   Hookah Bar
# 455                   Restaurant                       Lounge
# 457                       Lounge             Department Store
# 458                  Event Space  Eastern European Restaurant
# 459                   Theme Park             Sushi Restaurant
# 462                    BBQ Joint                         Café
# 468               Breakfast Spot                    Nightclub
# 487                        Hotel                  Music Venue
# 492                  Pizza Place                Grocery Store
# 496                  Pizza Place                         Café
# 497                   Restaurant                         Pool
# 498               Scenic Lookout         Fast Food Restaurant
#
# [80 rows x 8 columns]

# %% [markdown]
# Cluster 4

# %%
europe_merged.loc[europe_merged['Cluster Labels'] == 3, europe_merged.columns[[0] + list(range(5, europe_merged.shape[1]))]]
# Out:
#                     City 1st Most Common Venue 2nd Most Common Venue  \
# 34                Dublin                  Café           Coffee Shop
# 38            Birmingham                   Pub                   Bar
# 54            Nottingham                   Pub                   Bar
# 60             Sheffield                   Pub                   Bar
# 71               Bristol                  Café                   Pub
# 102            Leicester           Coffee Shop                   Pub
# 122                Leeds                   Bar                   Pub
# 140           Manchester                   Pub           Coffee Shop
# 150       Stoke-on-Trent                   Pub           Coffee Shop
# 160             Coventry                   Pub                 Hotel
# 176           Sunderland                   Pub    Italian Restaurant
# 188              Reading                   Pub           Coffee Shop
# 199   Kingston upon Hull                   Pub           Coffee Shop
# 200              Preston                   Pub           Coffee Shop
# 208              Newport                   Pub         Grocery Store
# 215              Swansea                   Pub           Coffee Shop
# 216             Bradford                   Pub     Indian Restaurant
# 219      Southend-on-Sea                   Pub                 Beach
# 246                Derby                   Pub                  Park
# 254             Plymouth                   Pub           Coffee Shop
# 256                Luton                   Pub         Grocery Store
# 264        Wolverhampton                   Pub           Supermarket
# 276          Southampton           Coffee Shop                   Pub
# 285            Blackpool                   Pub         Grocery Store
# 304        Milton Keynes                   Pub             Gastropub
# 309               Bexley                   Pub                  Park
# 333          Northampton                   Pub           Coffee Shop
# 343              Norwich                   Pub                  Café
# 374               Dudley                   Pub                  Park
# 386           Portsmouth                   Pub           Coffee Shop
# 387  Newcastle upon Tyne                   Pub           Coffee Shop
# 391                 Cork                   Pub                  Café
# 397               Sutton                   Pub                  Park
# 403              Swindon           Coffee Shop        Clothing Store
# 404        Dun Laoghaire                  Café                   Pub
# 420              Crawley                   Pub                 Hotel
# 426              Ipswich                   Pub           Coffee Shop
# 433                Wigan                   Pub           Coffee Shop
# 435              Croydon                  Park                   Pub
# 437              Walsall                   Pub           Coffee Shop
# 440            Mansfield                   Pub         Grocery Store
# 443               Oxford                   Pub                  Café
# 465           Warrington                   Pub         Grocery Store
# 472               Slough                 Hotel                   Pub
# 475         Peterborough                   Pub         Grocery Store
# 489            Cambridge                   Pub                  Café
# 491            Doncaster                   Pub         Grocery Store
#
#     3rd Most Common Venue         4th Most Common Venue 5th Most Common Venue  \
# 34                    Pub            Italian Restaurant            Restaurant
# 38      Indian Restaurant                   Coffee Shop                 Hotel
# 54                   Café                   Coffee Shop     Indian Restaurant
# 60            Coffee Shop                          Café                  Park
# 71                    Bar                   Coffee Shop    Italian Restaurant
# 102                  Park                           Bar    Italian Restaurant
# 122           Coffee Shop                          Café       Thai Restaurant
# 140                   Bar                         Hotel     Indian Restaurant
# 150                   Bar                          Park     Indian Restaurant
# 160                  Park                          Café     Indian Restaurant
# 176         Grocery Store                           Bar           Coffee Shop
# 188                   Bar                          Park      Asian Restaurant
# 199         Grocery Store                         Hotel           Supermarket
# 200    Italian Restaurant                          Park           Supermarket
# 208            Restaurant                         Hotel           Coffee Shop
# 215                  Café            Seafood Restaurant                 Beach
# 216                  Park                           Bar           Coffee Shop
# 219           Coffee Shop                   Supermarket           Pizza Place
# 246         Grocery Store                   Coffee Shop                Lounge
# 254                  Café                    Restaurant                  Park
# 256        Clothing Store                         Hotel  Gym / Fitness Center
# 264           Coffee Shop                 Grocery Store                 Hotel
# 276                  Park                          Café                   Bar
# 285                 Hotel                         Beach           Coffee Shop
# 304                  Café         Portuguese Restaurant                   Gym
# 309           Coffee Shop          Gym / Fitness Center        Clothing Store
# 333           Supermarket                          Café            Restaurant
# 343                  Park                           Bar           Coffee Shop
# 374           Supermarket          Gym / Fitness Center           Coffee Shop
# 386                  Café                History Museum                 Beach
# 387                   Bar                          Café     Indian Restaurant
# 391           Coffee Shop                    Restaurant          Burger Joint
# 397           Coffee Shop                          Café           Supermarket
# 403                   Pub                   Supermarket    Italian Restaurant
# 404           Coffee Shop                          Park                 Beach
# 420         Grocery Store          Gym / Fitness Center        Sandwich Place
# 426                   Bar                         Hotel         Grocery Store
# 433    Italian Restaurant                          Park     Indian Restaurant
# 435           Coffee Shop                          Café           Pizza Place
# 437         Movie Theater                Clothing Store  Gym / Fitness Center
# 440        Clothing Store                     Gastropub           Coffee Shop
# 443           Coffee Shop               Thai Restaurant          Burger Joint
# 465           Coffee Shop                           Bar        Sandwich Place
# 472                  Park  Theme Park Ride / Attraction    Italian Restaurant
# 475                 Hotel          Fast Food Restaurant           Coffee Shop
# 489          Burger Joint                   Coffee Shop                  Park
# 491           Coffee Shop                         Hotel           Supermarket
#
#       6th Most Common Venue   7th Most Common Venue
# 34                    Plaza            Cocktail Bar
# 38               Restaurant      Italian Restaurant
# 54                Bookstore            Dessert Shop
# 60            Burrito Place           Deli / Bodega
# 71               Restaurant             Pizza Place
# 102       Indian Restaurant    Gym / Fitness Center
# 122              Restaurant           Shopping Mall
# 140                Tea Room                    Café
# 150  Furniture / Home Store             Supermarket
# 160             Coffee Shop               Gastropub
# 176                   Beach             Supermarket
# 188          Clothing Store          Sandwich Place
# 199                     Bar      Chinese Restaurant
# 200                   Hotel           Grocery Store
# 208             Supermarket          Clothing Store
# 215                    Park  Furniture / Home Store
# 216             Pizza Place                    Café
# 219           Grocery Store                    Park
# 246                    Café       Indian Restaurant
# 254       Fish & Chips Shop                   Beach
# 256             Coffee Shop             Supermarket
# 264    Fast Food Restaurant                     Bar
# 276      Italian Restaurant       Indian Restaurant
# 285             Supermarket             Pizza Place
# 304      Turkish Restaurant            Burger Joint
# 309      Italian Restaurant           Grocery Store
# 333    Gym / Fitness Center                    Park
# 343                Tea Room             Pizza Place
# 374       Indian Restaurant                 Brewery
# 386    Gym / Fitness Center          Scenic Lookout
# 387      Italian Restaurant                   Hotel
# 391                     Bar                 Brewery
# 397        Sushi Restaurant       Korean Restaurant
# 403                    Café              Restaurant
# 404                  Bistro          Scenic Lookout
# 420       Indian Restaurant                    Park
# 426                    Café             Supermarket
# 433             Supermarket           Movie Theater
# 435               Gastropub      Italian Restaurant
# 437                    Park             Pizza Place
# 440             Supermarket    Fast Food Restaurant
# 443          Ice Cream Shop          History Museum
# 465                    Café                   Hotel
# 472          Airport Lounge       Indian Restaurant
# 475               Gastropub             Supermarket
# 489   Portuguese Restaurant                     Bar
# 491    Fast Food Restaurant          Clothing Store

# %% [markdown]
# Cluster 5

# %%
europe_merged.loc[europe_merged['Cluster Labels'] == 4, europe_merged.columns[[0] + list(range(5, europe_merged.shape[1]))]]
# Out:
#                       City 1st Most Common Venue        2nd Most Common Venue  \
# 21                  Munich                  Café                        Hotel
# 51                  Krakow                  Café                        Hotel
# 58                  Zagreb                  Café                          Bar
# 59                Sarajevo                  Café  Eastern European Restaurant
# 64       Frankfurt am Main                  Café                        Hotel
# 69                 Wroclaw                  Café                     Beer Bar
# 70                 Izhevsk                  Café         Gym / Fitness Center
# 79             Vladivostok                  Café                  Coffee Shop
# 87                  Poznan                  Café            Polish Restaurant
# 93            Novokuznetsk                  Café                         Park
# 100              Mykolayiv                  Café         Gym / Fitness Center
# 101    Naberezhnyye Chelny      Sushi Restaurant                         Café
# 112                  Gomel              Bus Stop                         Café
# 114                 Skopje                  Café                          Bar
# 121                  Kirov                  Café                         Park
# 125             Cheboksary                  Café         Gym / Fitness Center
# 130             Bratislava                  Café                  Coffee Shop
# 132             Sevastopol                  Café                        Beach
# 136               Szczecin                  Café                        Hotel
# 148                 Tirana                 Hotel                         Café
# 151                   Brno                  Café                          Pub
# 157              Wuppertal                  Café                  Supermarket
# 159                 Lublin                  Café                        Hotel
# 163           Thessaloniki                  Café                          Bar
# 168                 Kurgan           Supermarket                         Food
# 169                Vitebsk                  Café                Shopping Mall
# 171                Plovdiv                  Café                         Park
# 175             Simferopol                  Café                         Park
# 189                   Iasi                  Café                   Restaurant
# 197              Timisoara                  Café                   Restaurant
# ..                     ...                   ...                          ...
# 295            Nizhnekamsk                  Café            Electronics Store
# 298             Dzerzhinsk                  Café                Historic Site
# 315                Groznyy                  Café                   Restaurant
# 319                   Graz                  Café                          Bar
# 322             Banja Luka                  Café                   Restaurant
# 325                Messina                  Café                  Pizza Place
# 330                Rybinsk                  Café         Gym / Fitness Center
# 332               Freiburg                  Café            German Restaurant
# 338       Velikiy Novgorod                  Café                Historic Site
# 339             Centralniy                  Café                        River
# 344                Mokotow                  Café                         Park
# 359               Debrecen                  Café                   Restaurant
# 363                Tampere                  Café                         Park
# 367                Nicosia                  Café                          Bar
# 372                Armavir                  Café                        Hotel
# 385           Severodvinsk                  Café          Sporting Goods Shop
# 416                  Prato                  Café           Italian Restaurant
# 430                  Split            Restaurant                         Café
# 432                  Turku                  Café         Gym / Fitness Center
# 434            Kramators'k                  Café                         Park
# 446        Reggio Calabria           Pizza Place                         Café
# 448            Baranovichi                  Café                Grocery Store
# 452                  Patra                  Café                          Bar
# 470                 Pilsen                  Café                          Pub
# 471                Nazran'                  Café  Eastern European Restaurant
# 473                Piraeus                  Café             Greek Restaurant
# 476  Ludwigshafen am Rhein                  Café                         Park
# 480              Rubtsovsk                  Café           Athletics & Sports
# 482                Salavat                  Café                        Hotel
# 499                   Ruse                  Café                        Hotel
#
#            3rd Most Common Venue          4th Most Common Venue  \
# 21                Ice Cream Shop                          Plaza
# 51            Italian Restaurant                          Plaza
# 58                         Plaza                     Restaurant
# 59                    Restaurant                          Hotel
# 64                           Bar                     Art Museum
# 69                           Pub                          Hotel
# 70                   Coffee Shop                           Park
# 79                    Restaurant              Korean Restaurant
# 87                    Restaurant                           Park
# 93                           Gym                    Snack Place
# 100                         Park                    Gas Station
# 101                   Restaurant              Recreation Center
# 112                  Coffee Shop                          Hotel
# 114         Gym / Fitness Center                          Hotel
# 121             Sushi Restaurant                  Shopping Mall
# 125                   Restaurant                    Coffee Shop
# 130                          Pub                 Ice Cream Shop
# 132                          Gym                           Park
# 136                 Burger Joint                        Brewery
# 148           Italian Restaurant                            Bar
# 151                  Coffee Shop                        Theater
# 157                  Golf Course                      Drugstore
# 159                Shopping Mall                            Bar
# 163                 Dessert Shop                          Hotel
# 168          Japanese Restaurant                       Bus Stop
# 169                  Coffee Shop                     Restaurant
# 171                          Bar           Gym / Fitness Center
# 175                          Gym           Gym / Fitness Center
# 189                         Park                    Coffee Shop
# 197                       Bakery                    Coffee Shop
# ..                           ...                            ...
# 295                   Restaurant                           Park
# 298         Gym / Fitness Center                      Nightclub
# 315                 Dessert Shop                    Pizza Place
# 319          Austrian Restaurant                    Coffee Shop
# 322                          Bar                         Lounge
# 325                 Dessert Shop                     Restaurant
# 330                Shopping Mall                     Restaurant
# 332                        Hotel                          Plaza
# 338                   Restaurant                 History Museum
# 339         Caucasian Restaurant                    Bus Station
# 344                 Cocktail Bar  Vegetarian / Vegan Restaurant
# 359         Fast Food Restaurant                    Coffee Shop
# 363         Gym / Fitness Center                     Restaurant
# 367                  Coffee Shop                 Sandwich Place
# 372  Eastern European Restaurant                         Bakery
# 385                Movie Theater             Italian Restaurant
# 416                  Pizza Place                 Ice Cream Shop
# 430     Mediterranean Restaurant                   Cocktail Bar
# 432                          Bar        Scandinavian Restaurant
# 434                  Coffee Shop                    Pizza Place
# 446                        Beach             Italian Restaurant
# 448                         Park                       Bus Stop
# 452                 Dessert Shop                  Souvlaki Shop
# 470                         Park                     Restaurant
# 471          Monument / Landmark                          Hotel
# 473                Historic Site                   Dessert Shop
# 476                          Bar             Italian Restaurant
# 480                Train Station              French Restaurant
# 482                 Burger Joint                    Coffee Shop
# 499                          Bar                           Park
#
#              5th Most Common Venue        6th Most Common Venue  \
# 21                    Cocktail Bar            German Restaurant
# 51   Vegetarian / Vegan Restaurant                     Beer Bar
# 58        Mediterranean Restaurant                 Dessert Shop
# 59              Italian Restaurant                          Pub
# 64             Japanese Restaurant                         Park
# 69   Vegetarian / Vegan Restaurant                 Burger Joint
# 70                           Hotel                  Pizza Place
# 79             Japanese Restaurant                        Beach
# 87              Italian Restaurant                     Beer Bar
# 93                           Hotel                Historic Site
# 100                    Coffee Shop                   Restaurant
# 101                          Hotel                  Coffee Shop
# 112                  Train Station               Soccer Stadium
# 114                     Restaurant                       Bakery
# 121                    Coffee Shop                   Restaurant
# 125                         Resort                  Pizza Place
# 130                          Hotel                     Wine Bar
# 132               Sushi Restaurant                          Pub
# 136                    Pizza Place                Shopping Mall
# 148                   Cocktail Bar  Eastern European Restaurant
# 151                           Park        Vietnamese Restaurant
# 157                 Ice Cream Shop                          Bar
# 159                     Restaurant           Italian Restaurant
# 163                       Wine Bar             Greek Restaurant
# 168                           Lake                        Hotel
# 169                            Bar                         Park
# 171           Bulgarian Restaurant                Historic Site
# 175                   Burger Joint                   Restaurant
# 189            Romanian Restaurant             Department Store
# 197                           Park                          Bar
# ..                             ...                          ...
# 295                  Big Box Store             Sushi Restaurant
# 298                    Snack Place  Eastern European Restaurant
# 315                    Coffee Shop                        Hotel
# 319                          Hotel                   Restaurant
# 322                    Pizza Place                          Pub
# 325                 Clothing Store                    Nightclub
# 330                          Plaza                         Park
# 332             Italian Restaurant                   Restaurant
# 338                    Coffee Shop               Boarding House
# 339                           Park                   Restaurant
# 344                    Coffee Shop         Gym / Fitness Center
# 359                      Nightclub  Eastern European Restaurant
# 363                 Scenic Lookout                  Pizza Place
# 367                     Restaurant                 Burger Joint
# 372                    Pizza Place                    Gastropub
# 385                          Beach                   Restaurant
# 416                    Supermarket                   Restaurant
# 430                    Pizza Place                        Plaza
# 432                           Park                   Restaurant
# 434    Eastern European Restaurant            Electronics Store
# 446                 Ice Cream Shop                          Pub
# 448                         Bakery                 Dessert Shop
# 452               Pedestrian Plaza                  Coffee Shop
# 470                      Gastropub                 Burger Joint
# 471                  Train Station                         Farm
# 473                   Fish Taverna                         Park
# 476                          Hotel            German Restaurant
# 480             Italian Restaurant                Shopping Mall
# 482                    Pizza Place                         Park
# 499                     Restaurant                  Supermarket
#
#              7th Most Common Venue
# 21                          Church
# 51                             Bar
# 58                          Hostel
# 59                     Coffee Shop
# 64                     Coffee Shop
# 69                            Park
# 70                   Big Box Store
# 79                      Hookah Bar
# 87                     Coffee Shop
# 93                   Big Box Store
# 100                    Pizza Place
# 101                           Park
# 112                 Hardware Store
# 114                    Coffee Shop
# 121                          Hotel
# 125                          Hotel
# 130                       Beer Bar
# 132                     Restaurant
# 136           Fast Food Restaurant
# 148                    Coffee Shop
# 151                         Bistro
# 157                     Restaurant
# 159                          Plaza
# 163                 Ice Cream Shop
# 168                           Café
# 169                          Plaza
# 171                    Supermarket
# 175                    Pizza Place
# 189             Italian Restaurant
# 197                    Salad Place
# ..                             ...
# 295           Fast Food Restaurant
# 298              Electronics Store
# 315               Sushi Restaurant
# 319                         Bakery
# 322                          Hotel
# 325                            Pub
# 330                   Skating Rink
# 332                           Park
# 338                          Beach
# 339                   Cupcake Shop
# 344               Sushi Restaurant
# 359                 Clothing Store
# 363                     Steakhouse
# 367               Greek Restaurant
# 372                  Train Station
# 385                   Dessert Shop
# 416                            Pub
# 430                            Bar
# 432  Vegetarian / Vegan Restaurant
# 434           Fast Food Restaurant
# 446                   Cocktail Bar
# 448                   Gourmet Shop
# 452                      Bookstore
# 470               Sushi Restaurant
# 471                 Farmers Market
# 473                 History Museum
# 476          Vietnamese Restaurant
# 480              Electronics Store
# 482              German Restaurant
# 499                    Pizza Place
#
# [76 rows x 8 columns]

# %% [markdown]
# Cluster 6

# %%
europe_merged.loc[europe_merged['Cluster Labels'] == 5, europe_merged.columns[[0] + list(range(5, europe_merged.shape[1]))]]
# Out:
#                    City    1st Most Common Venue 2nd Most Common Venue  \
# 0                Moscow              Yoga Studio                 Hotel
# 1                London                    Hotel               Theater
# 2      Saint Petersburg              Coffee Shop               Theater
# 5                  Kyiv     Caucasian Restaurant                 Hotel
# 7                 Paris                    Plaza                 Hotel
# 11              Hamburg                    Hotel           Coffee Shop
# 12               Warsaw             Cocktail Bar                  Café
# 13               Vienna                    Hotel                 Plaza
# 15            Stockholm  Scandinavian Restaurant                 Hotel
# 19     Nizhniy Novgorod                    Hotel           Coffee Shop
# 20             Belgrade                     Café                   Bar
# 22                Milan                    Hotel              Boutique
# 23               Prague                     Café                 Hotel
# 24           Copenhagen                 Beer Bar                  Café
# 35             Brussels                      Bar        Chocolate Shop
# 37               Odessa                    Hotel                  Park
# 44            Liverpool                    Hotel           Coffee Shop
# 49            Marseille                    Hotel     French Restaurant
# 50                 Lodz              Coffee Shop                 Hotel
# 52                 Riga                    Hotel                  Park
# 53            Amsterdam                    Hotel           Coffee Shop
# 55                 Lviv                    Hotel           Coffee Shop
# 62               Athens            Historic Site           Coffee Shop
# 68             Chisinau                    Hotel                  Park
# 72            Yaroslavl                    Hotel           Coffee Shop
# 74            Rotterdam              Coffee Shop                   Bar
# 76              Glasgow                      Bar           Coffee Shop
# 82                 Oslo              Coffee Shop                   Bar
# 85          Duesseldorf      Japanese Restaurant                 Hotel
# 86            Goeteborg              Coffee Shop                 Hotel
# ..                  ...                      ...                   ...
# 349              Rennes                    Hotel                   Bar
# 350               Torun                     Café           Coffee Shop
# 351              Kielce                    Hotel  Fast Food Restaurant
# 353              Oradea                    Hotel           Supermarket
# 356                Linz               Restaurant                 Hotel
# 358     Ivano-Frankivsk                    Hotel           Coffee Shop
# 362  Vasyl'evsky Ostrov                  Theater                  Park
# 366           Favoriten                    Hotel   Austrian Restaurant
# 380            Aberdeen                      Bar                 Hotel
# 381               Reims        French Restaurant                 Hotel
# 396      Praga Poludnie                     Park          Cocktail Bar
# 400          Donaustadt                    Hotel   Austrian Restaurant
# 402            Le Havre                    Hotel         Train Station
# 409              Geneve                    Hotel                   Bar
# 410      Cergy-Pontoise            Train Station  Fast Food Restaurant
# 414               Liege                      Bar            Restaurant
# 418           Groningen               Restaurant           Coffee Shop
# 425             Amadora    Portuguese Restaurant                 Hotel
# 431       Saint-Etienne            Train Station                 Plaza
# 441             Olsztyn                    Hotel  Fast Food Restaurant
# 447                Arad                     Lake                 Hotel
# 449              Toulon                    Beach  Fast Food Restaurant
# 450              Angers        French Restaurant           Supermarket
# 456               Breda                      Bar           Coffee Shop
# 466              Szeged                     Café                  Park
# 467               Basel                     Café                 Hotel
# 477         Floridsdorf      Austrian Restaurant                 Hotel
# 488            Grenoble        French Restaurant                   Bar
# 490             Rzeszow                    Hotel                   Pub
# 494       Admiralteisky                    Hotel               Theater
#
#            3rd Most Common Venue        4th Most Common Venue  \
# 0                           Park                  Art Gallery
# 1                     Art Museum                 Cocktail Bar
# 2                          Hotel                   Art Museum
# 5                   Cocktail Bar                       Bakery
# 7              French Restaurant                    Bookstore
# 11                          Café                 Cocktail Bar
# 12                         Hotel             Sushi Restaurant
# 13           Austrian Restaurant                   Restaurant
# 15                   Coffee Shop                         Café
# 19                Scenic Lookout                Historic Site
# 20                  Cocktail Bar  Eastern European Restaurant
# 22                         Plaza                  Pizza Place
# 23            Italian Restaurant                         Park
# 24                   Coffee Shop                 Cocktail Bar
# 35                Sandwich Place                        Hotel
# 37                   Coffee Shop                     Wine Bar
# 44                          Café                          Pub
# 49          Provençal Restaurant                          Bar
# 50                          Park                         Café
# 52                           Bar                   Restaurant
# 53                Breakfast Spot                  Yoga Studio
# 55                      Wine Bar                       Church
# 62                          Café                          Bar
# 68                          Café                  Coffee Shop
# 72                         Plaza                          Gym
# 74                         Hotel                         Café
# 76                         Hotel                          Pub
# 82             Indian Restaurant      Scandinavian Restaurant
# 85                           Bar                      Brewery
# 86                  Burger Joint                         Café
# ..                           ...                          ...
# 349                         Park         Fast Food Restaurant
# 350         Fast Food Restaurant                     Creperie
# 351                         Café                   Restaurant
# 353           Italian Restaurant                  Pizza Place
# 356                          Bar           Italian Restaurant
# 358                   Restaurant                          Pub
# 362                Historic Site                        Hotel
# 366                        Plaza               Ice Cream Shop
# 380                         Café                     Beer Bar
# 381                     Wine Bar       Furniture / Home Store
# 396                      Theater                         Café
# 400                   Restaurant               Ice Cream Shop
# 402                Shopping Mall            French Restaurant
# 409            French Restaurant                        Plaza
# 410                  Supermarket            French Restaurant
# 414           Italian Restaurant                  Coffee Shop
# 418                          Bar                         Café
# 425                         Park                       Garden
# 431                  Supermarket                   Art Museum
# 441                          Pub                         Café
# 447                  Zoo Exhibit          Filipino Restaurant
# 449                        Hotel                  Supermarket
# 450                          Bar                         Park
# 456                   Restaurant            French Restaurant
# 466         Hungarian Restaurant                       Bakery
# 467                          Bar                        Plaza
# 477                   Restaurant                         Park
# 488                        Hotel                        Plaza
# 490  Eastern European Restaurant                    Nightclub
# 494                   Art Museum                        Plaza
#
#              5th Most Common Venue    6th Most Common Venue  \
# 0               Salon / Barbershop                     Road
# 1                             Park              Art Gallery
# 2                            Plaza            Historic Site
# 5                      Coffee Shop                     Park
# 7                     Cocktail Bar       Italian Restaurant
# 11                      Steakhouse               Restaurant
# 12                            Park              Coffee Shop
# 13                            Park               Art Museum
# 15                    Cocktail Bar                     Park
# 19                           Plaza               Steakhouse
# 20                           Hotel           Ice Cream Shop
# 22                  Ice Cream Shop       Italian Restaurant
# 23                  Ice Cream Shop             Cocktail Bar
# 24                          Bakery  Scandinavian Restaurant
# 35              Italian Restaurant             Concert Hall
# 37                      Restaurant                    Plaza
# 44              Italian Restaurant                      Bar
# 49                           Plaza                 Tea Room
# 50              Italian Restaurant                      Bar
# 52     Eastern European Restaurant                     Café
# 53                             Bar                Bookstore
# 55                           Plaza                Bookstore
# 62                    Cocktail Bar             Dessert Shop
# 68                          Bakery              Supermarket
# 72              Russian Restaurant               Restaurant
# 74                            Park           Ice Cream Shop
# 76                    Cocktail Bar               Restaurant
# 82                      Restaurant         Tapas Restaurant
# 85                            Café              Coffee Shop
# 86         Scandinavian Restaurant                      Pub
# ..                             ...                      ...
# 349                       Creperie                    Plaza
# 350                          Hotel              Pizza Place
# 351                      Multiplex              Pizza Place
# 353                           Café              Coffee Shop
# 356                           Café             Burger Joint
# 358                          Plaza                     Café
# 362                    Coffee Shop           Scenic Lookout
# 366                           Park                   Palace
# 380                           Park           Sandwich Place
# 381                          Plaza     Fast Food Restaurant
# 396  Vegetarian / Vegan Restaurant              Coffee Shop
# 400                         Bakery             Concert Hall
# 402                     Restaurant     Fast Food Restaurant
# 409                           Park             Dessert Shop
# 410                          Hotel      Japanese Restaurant
# 414                           Park        French Restaurant
# 418                        Theater                Gastropub
# 425                     Restaurant                   Museum
# 431                    Coffee Shop        French Restaurant
# 441                     Restaurant              Supermarket
# 447                   Fishing Spot             Fish Taverna
# 449                            Bar        French Restaurant
# 450           Fast Food Restaurant      Sporting Goods Shop
# 456             Italian Restaurant              Supermarket
# 466                    Coffee Shop                    Hotel
# 467               Swiss Restaurant                     Park
# 477                 Ice Cream Shop              Coffee Shop
# 488           Fast Food Restaurant               Restaurant
# 490                           Café       Italian Restaurant
# 494                            Spa             Concert Hall
#
#              7th Most Common Venue
# 0                       Hookah Bar
# 1                       Steakhouse
# 2                     Concert Hall
# 5                          Theater
# 7                         Wine Bar
# 11               French Restaurant
# 12   Vegetarian / Vegan Restaurant
# 13                  Ice Cream Shop
# 15                       Bookstore
# 19                            Café
# 20                         Theater
# 22                      Art Museum
# 23                    Burger Joint
# 24                            Park
# 35                     Coffee Shop
# 37              Italian Restaurant
# 44                  History Museum
# 49                          Church
# 50                     Pizza Place
# 52                     Coffee Shop
# 53               French Restaurant
# 55                            Café
# 62                  History Museum
# 68            Gym / Fitness Center
# 72                             Bar
# 74                          Bakery
# 76              Seafood Restaurant
# 82                     Pizza Place
# 85                            Park
# 86    Theme Park Ride / Attraction
# ..                             ...
# 349              French Restaurant
# 350                            Pub
# 351                  Shopping Mall
# 353                           Park
# 356            Austrian Restaurant
# 358                           Park
# 362                     Art Museum
# 366               Asian Restaurant
# 380                            Pub
# 381                  Bowling Alley
# 396               Sushi Restaurant
# 400                           Park
# 402                            Bar
# 409                   Cocktail Bar
# 410                     Steakhouse
# 414                          Plaza
# 418                          Hotel
# 425                 Ice Cream Shop
# 431                          Hotel
# 441                  Historic Site
# 447                    Fish Market
# 449                  Shopping Mall
# 450                  Shopping Mall
# 456                          Hotel
# 466                          Plaza
# 467              French Restaurant
# 477                           Café
# 488                    Supermarket
# 490                     Restaurant
# 494                    Coffee Shop
#
# [105 rows x 8 columns]

# %% [markdown]
# Cluster 7

# %%
europe_merged.loc[europe_merged['Cluster Labels'] == 6, europe_merged.columns[[0] + list(range(5, europe_merged.shape[1]))]]
# Out:
#                            City     1st Most Common Venue  \
# 4                        Madrid                     Hotel
# 14                    Barcelona                     Hotel
# 47                     Valencia                     Plaza
# 56                      Sevilla          Tapas Restaurant
# 61                     Zaragoza                     Hotel
# 88                       Malaga                     Hotel
# 126                      Murcia                Restaurant
# 137                       Palma          Tapas Restaurant
# 144  Las Palmas de Gran Canaria                Restaurant
# 162                      Bilbao          Tapas Restaurant
# 177                    Alicante          Tapas Restaurant
# 179                     Cordoba        Spanish Restaurant
# 190                  Valladolid          Tapas Restaurant
# 218                        Vigo                Restaurant
# 235                       Gijon        Spanish Restaurant
# 250                    Eixample                     Hotel
# 257   L'Hospitalet de Llobregat          Tapas Restaurant
# 259                      Latina        Spanish Restaurant
# 263                 Carabanchel        Spanish Restaurant
# 277                    A Coruna        Spanish Restaurant
# 280          Puente de Vallecas                Restaurant
# 290                  Sant Marti                     Hotel
# 292           Gasteiz / Vitoria                       Bar
# 294                     Granada                     Hotel
# 303                       Elche        Spanish Restaurant
# 308               Ciudad Lineal        Spanish Restaurant
# 317                      Oviedo        Spanish Restaurant
# 318      Santa Cruz de Tenerife          Tapas Restaurant
# 324         Fuencarral-El Pardo        Spanish Restaurant
# 326                    Badalona          Tapas Restaurant
# 346                   Cartagena        Spanish Restaurant
# 347                    Terrassa  Mediterranean Restaurant
# 352        Jerez de la Frontera        Spanish Restaurant
# 354                    Sabadell                      Park
# 355                    Mostoles        Spanish Restaurant
# 357           Alcala de Henares                Restaurant
# 377                    Pamplona        Spanish Restaurant
# 379                 Fuenlabrada        Spanish Restaurant
# 395                     Almeria          Tapas Restaurant
# 401                     Leganes                      Park
# 405               San Sebastian          Tapas Restaurant
# 412              Sants-Montjuic          Tapas Restaurant
# 413                   Santander        Spanish Restaurant
# 421        Castello de la Plana        Spanish Restaurant
# 424                      Burgos        Spanish Restaurant
# 445                    Albacete        Spanish Restaurant
# 451              Horta-Guinardo                     Hotel
# 453                    Alcorcon        Spanish Restaurant
# 461                      Getafe        Spanish Restaurant
# 464                  Nou Barris                     Hotel
# 479                   Hortaleza        Spanish Restaurant
# 495         San Blas-Canillejas                Restaurant
#
#         2nd Most Common Venue     3rd Most Common Venue  \
# 4                       Plaza                Restaurant
# 14           Tapas Restaurant        Spanish Restaurant
# 47         Italian Restaurant                     Hotel
# 56                      Plaza        Spanish Restaurant
# 61                 Restaurant            Breakfast Spot
# 88           Tapas Restaurant        Spanish Restaurant
# 126        Spanish Restaurant          Tapas Restaurant
# 137                      Café                Restaurant
# 144        Spanish Restaurant                     Plaza
# 162        Spanish Restaurant                     Hotel
# 177               Coffee Shop        Spanish Restaurant
# 179                     Hotel                      Park
# 190                     Plaza                       Bar
# 218          Tapas Restaurant                     Beach
# 235                     Hotel                      Park
# 250          Tapas Restaurant               Coffee Shop
# 257                      Park        Spanish Restaurant
# 259                     Plaza                      Park
# 263                     Plaza                     Hotel
# 277                Restaurant          Tapas Restaurant
# 280                     Hotel          Tapas Restaurant
# 290          Tapas Restaurant                     Plaza
# 292                Restaurant        Spanish Restaurant
# 294          Tapas Restaurant        Spanish Restaurant
# 303  Mediterranean Restaurant                Restaurant
# 308                Restaurant                     Hotel
# 317                Restaurant               Coffee Shop
# 318                     Plaza        Spanish Restaurant
# 324                Restaurant                     Hotel
# 326                     Beach                Restaurant
# 346            Clothing Store                     Hotel
# 347                Restaurant                      Park
# 352          Tapas Restaurant                     Hotel
# 354                Restaurant               Supermarket
# 355            Clothing Store                Restaurant
# 357                      Café  Mediterranean Restaurant
# 377                     Hotel                      Park
# 379                Restaurant      Gym / Fitness Center
# 395        Spanish Restaurant                     Beach
# 401        Spanish Restaurant        Italian Restaurant
# 405        Spanish Restaurant                     Hotel
# 412                      Park                     Hotel
# 413                     Beach                Restaurant
# 421                       Pub               Pizza Place
# 424                     Hotel                Restaurant
# 445                     Hotel          Tapas Restaurant
# 451          Tapas Restaurant               Coffee Shop
# 453                Restaurant        Italian Restaurant
# 461                      Park              Cocktail Bar
# 464          Tapas Restaurant        Spanish Restaurant
# 479          Tapas Restaurant       Japanese Restaurant
# 495        Spanish Restaurant                     Hotel
#
#         4th Most Common Venue 5th Most Common Venue     6th Most Common Venue  \
# 4          Spanish Restaurant                  Café                   Theater
# 14                      Plaza           Coffee Shop                 Bookstore
# 47                Coffee Shop    Spanish Restaurant                      Park
# 56             Ice Cream Shop                 Hotel                      Café
# 61         Spanish Restaurant         Train Station                     Plaza
# 88                 Restaurant            Art Museum                  Beer Bar
# 126                     Plaza                  Park                     Hotel
# 137               Coffee Shop                 Plaza                     Hotel
# 144                      Park      Tapas Restaurant               Coffee Shop
# 162                     Plaza                  Café                       Bar
# 177                     Plaza           Pizza Place                Restaurant
# 179          Tapas Restaurant                 Plaza              Cocktail Bar
# 190        Spanish Restaurant                 Hotel                      Café
# 218                     Hotel    Seafood Restaurant                      Café
# 235                Restaurant               Brewery                     Beach
# 250                 Bookstore          Cocktail Bar            Ice Cream Shop
# 257                 Bookstore           Pizza Place               Coffee Shop
# 259                      Café        Ice Cream Shop                     Hotel
# 263                      Café            Art Museum          Tapas Restaurant
# 277                     Plaza               Brewery                      Park
# 280        Spanish Restaurant            Art Museum                      Park
# 290             Historic Site    Spanish Restaurant                      Park
# 292          Tapas Restaurant                 Plaza                 Gastropub
# 294             Historic Site                 Plaza                      Café
# 303          Tapas Restaurant     Paella Restaurant                     Plaza
# 308          Tapas Restaurant   Japanese Restaurant                  Boutique
# 317                       Bar                 Hotel                     Plaza
# 318                     Hotel            Restaurant               Art Gallery
# 324                    Bakery  Gym / Fitness Center              Burger Joint
# 326                      Park         Historic Site  Mediterranean Restaurant
# 346                       Bar         Historic Site          Tapas Restaurant
# 347                     Plaza        Breakfast Spot          Tapas Restaurant
# 352                Restaurant         Shopping Mall            Clothing Store
# 354  Mediterranean Restaurant                Bakery        Spanish Restaurant
# 355         Food & Drink Shop             Gastropub              Burger Joint
# 357          Tapas Restaurant                   Bar        Spanish Restaurant
# 377          Tapas Restaurant                 Plaza                Restaurant
# 379               Coffee Shop           Pizza Place                      Park
# 395                Restaurant                  Café                     Hotel
# 401      Gym / Fitness Center          Cocktail Bar              Burger Joint
# 405                Restaurant                   Bar            Scenic Lookout
# 412        Spanish Restaurant           Pizza Place        Italian Restaurant
# 413          Tapas Restaurant    Seafood Restaurant                     Hotel
# 421  Mediterranean Restaurant                 Beach                     Plaza
# 424                       Bar                  Café         Electronics Store
# 445            Breakfast Spot                  Café            Ice Cream Shop
# 451              Cocktail Bar         Historic Site                 Bookstore
# 453              Burger Joint                  Park                       Gym
# 461                       Bar   American Restaurant        Italian Restaurant
# 464             Historic Site        Ice Cream Shop                  Wine Bar
# 479                Restaurant                 Hotel               Coffee Shop
# 495       Japanese Restaurant      Tapas Restaurant                Art Museum
#
#         7th Most Common Venue
# 4                         Bar
# 14                Pizza Place
# 47                 Restaurant
# 56   Mediterranean Restaurant
# 61                Supermarket
# 88                      Plaza
# 126                      Café
# 137  Mediterranean Restaurant
# 144                       Bar
# 162                Restaurant
# 177                     Hotel
# 179                       Bar
# 190  Mediterranean Restaurant
# 218                       Bar
# 235          Tapas Restaurant
# 250        Spanish Restaurant
# 257                     Hotel
# 259          Tapas Restaurant
# 263                      Park
# 277               Coffee Shop
# 280               Art Gallery
# 290            Ice Cream Shop
# 292                      Park
# 294            Scenic Lookout
# 303                     Hotel
# 308            Ice Cream Shop
# 317                      Park
# 318                      Café
# 324             Grocery Store
# 326               Pizza Place
# 346               Coffee Shop
# 347        Italian Restaurant
# 352                     Plaza
# 354       Japanese Restaurant
# 355        Italian Restaurant
# 357                       Gym
# 377                       Bar
# 379              Burger Joint
# 395  Mediterranean Restaurant
# 401               Art Gallery
# 405                     Beach
# 412               Coffee Shop
# 413               Sports Club
# 421          Tapas Restaurant
# 424            History Museum
# 445                       Bar
# 451            Ice Cream Shop
# 453                 Gastropub
# 461      Gym / Fitness Center
# 464               Coffee Shop
# 479                  Boutique
# 495                  Boutique
